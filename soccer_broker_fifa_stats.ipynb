# %%
## all imports
import requests
from bs4 import BeautifulSoup
import time
import operator
import socket
#import cPickle
import re # regular expressions

import pandas as pd
from pandas import DataFrame


import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

#from secret import *

#This code is to import the libraries we will ptentially be using during the execution of the tasks I have been assigned to
# data analysis and wrangling
import pandas as pd
import pickle
import numpy as np
import random as rnd
from datetime import timedelta
import scipy
from scipy import stats
#Limiting floats output to 3 decimal points
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) 

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# machine learning and metrics
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score, make_scorer, mean_squared_error
from sklearn.model_selection import KFold,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression, BayesianRidge, ElasticNet, Lasso, SGDRegressor, Ridge
from sklearn.kernel_ridge import KernelRidge
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor,GradientBoostingRegressor,RandomForestRegressor
from sklearn.svm import SVC, LinearSVC, SVR, LinearSVR
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings('ignore')
import urllib
import urllib.request
import os
from string import ascii_lowercase

# %%
print(savedplayerdata_detailed_all)
# Out:
# /nPosition:,
#
#
#
# Goalkeeper
# Defenders
# Midfielders
# Forwards
#
#
# /nNationality:,
#
#
# All
# Afghanistan
# Albania
# Algeria
# American Samoa
# American Virgin Islands
# Andorra
# Angola
# Anguilla
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bonaire
# Bosnia-Herzegovina
# Botsuana
# Brazil
# British Virgin Islands
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Cayman-Inseln
# Central African Republic
# Chad
# Chile
# China
# Chinese Taipei (Taiwan)
# Christmas Island
# Colombia
# Comoros
# Congo
# Cookinseln
# Costa Rica
# Cote d'Ivoire
# Croatia
# CSSR
# Cuba
# Curacao
# Cyprus
# Czech Republic
# DDR
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# DR Congo
# Ecuador
# Egypt
# El Salvador
# England
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Falkland Islands
# Faroe Island
# Federated States of Micronesia
# Fiji
# Finland
# France
# French Guiana
# Gabon
# Georgia
# Germany
# Ghana
# Gibraltar
# Greece
# Greenland
# Grenada
# Guadeloupe
# Guam
# Guatemala
# Guernsey
# Guinea
# Guinea-Bissau
# Guyana
# Haiti
# Honduras
# Hongkong
# Hungary
# Iceland
# India
# Indonesia
# Iran
# Iraq
# Ireland
# Isle of Man
# Israel
# Italy
# Jamaica
# Japan
# Jersey
# Jordan
# Jugoslawien (SFR)
# Kazakhstan
# Kenya
# Kiribati
# Korea, North
# Korea, South
# Kosovo
# Kuwait
# Kyrgyzstan
# Laos
# Latvia
# Lebanon
# Lesotho
# Liberia
# Libya
# Liechtenstein
# Lithuania
# Luxembourg
# Macao
# Macedonia
# Madagascar
# Malawi
# Malaysia
# Maldives
# Mali
# Malta
# Mariana Islands
# Marshall Islands
# Martinique
# Mauritania
# Mauritius
# Mexico
# Moldova
# Monaco
# Mongolia
# Montenegro
# Montserrat
# Morocco
# Mozambique
# Myanmar
# Namibia
# Nauru
# Nepal
# Netherlands
# Netherlands Antilles
# Netherlands East India
# Neukaledonien
# New Zealand
# Nicaragua
# Niger
# Nigeria
# Niue
# Northern Ireland
# Norway
# Oman
# Osttimor
# Pakistan
# Palästina
# Palau
# Panama
# Papua New Guinea
# Paraguay
# People's republic of the Congo
# Peru
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Réunion
# Romania
# Russia
# Rwanda
# Saarland
# Saint-Martin
# Samoa
# San Marino
# Sao Tome and Principe
# Saudi Arabia
# Scotland
# Senegal
# Serbia
# Serbia and Montenegro
# Seychelles
# Sierra Leone
# Singapore
# Sint Maarten
# Slovakia
# Slovenia
# Solomon Islands
# Somalia
# South Africa
# Southern Sudan
# Spain
# Sri Lanka
# St. Kitts & Nevis
# St. Lucia
# St. Vincent & Grenadinen
# Sudan
# Suriname
# Swaziland
# Sweden
# Switzerland
# Syria
# Tahiti
# Tajikistan
# Tanzania
# Thailand
# The Gambia
# Tibet
# Togo
# Tonga
# Trinidad and Tobago
# Tunisia
# Turkey
# Turkmenistan
# Turks- and Caicosinseln
# Tuvalu
# UdSSR
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States
# Uruguay
# Uzbekistan
# Vanuatu
# Vatican
# Venezuela
# Vietnam
# Wales
# Yemen
# Yugoslavia (Republic)
# Zaire
# Zambia
# Zanzibar
# Zimbabwe
#
#
# /n
#
#                                     ,
#  /n/n1,
#
#
#
#
# Kylian Mbappé
#
#
# Right Winger
#
#
# ,
#  ,
# Kylian Mbappé ,Right Winger,,,19,17.12.2018,200,00 Mill. €,200,00 Mill. €/n
#  ,
# Kylian Mbappé /nRight Winger/n2,
#
#
#
#
# Neymar
#
#
# Left Winger
#
#
# ,
#  ,
# Neymar ,Left Winger,,,25,24.01.2018,180,00 Mill. €,180,00 Mill. €/n
#  ,
# Neymar /nLeft Winger/n3,
#
#
#
#
# Lionel Messi
#
#
# Right Winger
#
#
# ,
#  ,
# Lionel Messi ,Right Winger,,,30,01.01.2018,180,00 Mill. €,160,00 Mill. €/n
#  ,
# Lionel Messi /nRight Winger/n4,
#
#
#
#
# Mohamed Salah
#
#
# Right Winger
#
#
# ,
#  ,
# Mohamed Salah ,Right Winger,,,25,28.05.2018,150,00 Mill. €,150,00 Mill. €/n
#  ,
# Mohamed Salah /nRight Winger/n5,
#
#
#
#
# Harry Kane
#
#
# Centre-Forward
#
#
# ,
#  ,
# Harry Kane ,Centre-Forward,,,24,28.05.2018,150,00 Mill. €,150,00 Mill. €/n
#  ,
# Harry Kane /nCentre-Forward/n6,
#
#
#
#
# Antoine Griezmann
#
#
# Centre-Forward
#
#
# ,
#  ,
# Antoine Griezmann ,Centre-Forward,,,27,31.10.2018,150,00 Mill. €,150,00 Mill. €/n
#  ,
# Antoine Griezmann /nCentre-Forward/n7,
#
#
#
#
# Kevin De Bruyne
#
#
# Attacking Midfield
#
#
# ,
#  ,
# Kevin De Bruyne ,Attacking Midfield,,,26,28.05.2018,150,00 Mill. €,150,00 Mill. €/n
#  ,
# Kevin De Bruyne /nAttacking Midfield/n8,
#
#
#
#
# Philippe Coutinho
#
#
# Attacking Midfield
#
#
# ,
#  ,
# Philippe Coutinho ,Attacking Midfield,,,26,31.10.2018,150,00 Mill. €,140,00 Mill. €/n
#  ,
# Philippe Coutinho /nAttacking Midfield/n9,
#
#
#
#
# Eden Hazard
#
#
# Left Winger
#
#
# ,
#  ,
# Eden Hazard ,Left Winger,,,27,17.10.2018,150,00 Mill. €,150,00 Mill. €/n
#  ,
# Eden Hazard /nLeft Winger/n10,
#
#
#
#
# Raheem Sterling
#
#
# Right Winger
#
#
# ,
#  ,
# Raheem Sterling ,Right Winger,,,24,19.12.2018,120,00 Mill. €,120,00 Mill. €/n
#  ,
# Raheem Sterling /nRight Winger/n11,
#
#
#
#
# Cristiano Ronaldo
#
#
# Left Winger
#
#
# ,
#  ,
# Cristiano Ronaldo ,Left Winger,,,29,22.10.2014,120,00 Mill. €,100,00 Mill. €/n
#  ,
# Cristiano Ronaldo /nLeft Winger/n12,
#
#
#
#
# Paulo Dybala
#
#
# Second Striker
#
#
# ,
#  ,
# Paulo Dybala ,Second Striker,,,24,07.06.2018,110,00 Mill. €,110,00 Mill. €/n
#  ,
# Paulo Dybala /nSecond Striker/n13,
#
#
#
#
# N'Golo Kanté
#
#
# Central Midfield
#
#
# ,
#  ,
# N'Golo Kanté ,Central Midfield,,,27,19.12.2018,100,00 Mill. €,100,00 Mill. €/n
#  ,
# N'Golo Kanté /nCentral Midfield/n14,
#
#
#
#
# Dele Alli
#
#
# Attacking Midfield
#
#
# ,
#  ,
# Dele Alli ,Attacking Midfield,,,22,28.05.2018,100,00 Mill. €,100,00 Mill. €/n
#  ,
# Dele Alli /nAttacking Midfield/n15,
#
#
#
#
# Leroy Sané
#
#
# Left Winger
#
#
# ,
#  ,
# Leroy Sané ,Left Winger,,,22,19.12.2018,100,00 Mill. €,100,00 Mill. €/n
#  ,
# Leroy Sané /nLeft Winger/n16,
#
#
#
#
# Romelu Lukaku
#
#
# Centre-Forward
#
#
# ,
#  ,
# Romelu Lukaku ,Centre-Forward,,,25,16.07.2018,100,00 Mill. €,85,00 Mill. €/n
#  ,
# Romelu Lukaku /nCentre-Forward/n17,
#
#
#
#
# Mauro Icardi
#
#
# Centre-Forward
#
#
# ,
#  ,
# Mauro Icardi ,Centre-Forward,,,25,20.12.2018,100,00 Mill. €,100,00 Mill. €/n
#  ,
# Mauro Icardi /nCentre-Forward/n18,
#
#
#
#
# Marco Asensio
#
#
# Left Winger
#
#
# ,
#  ,
# Marco Asensio ,Left Winger,,,22,31.10.2018,90,00 Mill. €,80,00 Mill. €/n
#  ,
# Marco Asensio /nLeft Winger/n19,
#
#
#
#
# Sergej Milinkovic-Savic
#
#
# Central Midfield
#
#
# ,
#  ,
# Sergej Milinkovic-Savic ,Central Midfield,,,23,07.06.2018,90,00 Mill. €,75,00 Mill. €/n
#  ,
# Sergej Milinkovic-Savic /nCentral Midfield/n20,
#
#
#
#
# Saúl Ñíguez
#
#
# Central Midfield
#
#
# ,
#  ,
# Saúl Ñíguez ,Central Midfield,,,23,31.10.2018,90,00 Mill. €,90,00 Mill. €/n
#  ,
# Saúl Ñíguez /nCentral Midfield/n21,
#
#
#
#
# Paul Pogba
#
#
# Central Midfield
#
#
# ,
#  ,
# Paul Pogba ,Central Midfield,,,24,02.01.2018,90,00 Mill. €,80,00 Mill. €/n
#  ,
# Paul Pogba /nCentral Midfield/n22,
#
#
#
#
# Isco
#
#
# Attacking Midfield
#
#
# ,
#  ,
# Isco ,Attacking Midfield,,,26,31.10.2018,90,00 Mill. €,75,00 Mill. €/n
#  ,
# Isco /nAttacking Midfield/n23,
#
#
#
#
# Luis Suárez
#
#
# Centre-Forward
#
#
# ,
#  ,
# Luis Suárez ,Centre-Forward,,,28,22.11.2015,90,00 Mill. €,60,00 Mill. €/n
#  ,
# Luis Suárez /nCentre-Forward/n24,
#
#
#
#
# Gareth Bale
#
#
# Right Winger
#
#
# ,
#  ,
# Gareth Bale ,Right Winger,,,26,15.07.2016,90,00 Mill. €,80,00 Mill. €/n
#  ,
# Gareth Bale /nRight Winger/n25,
#
#
#
#
# Robert Lewandowski
#
#
# Centre-Forward
#
#
# ,
#  ,
# Robert Lewandowski ,Centre-Forward,,,29,04.04.2018,90,00 Mill. €,70,00 Mill. €/n
#  ,
# Robert Lewandowski /nCentre-Forward

# %%
anchor = form.find("a",
href=re.compile("http://www.meetup.com/PyLadiesMTL/messages/boards/thread/"))

# %%
import sqlite3 as lite
database = 'database.sqlite'
conn = lite.connect(database)

query='SELECT * FROM Player_Attributes as PA JOIN Player as P on PA.player_api_id=P.player_api_id GROUP BY P.player_name,PA.date'

# 2015/2016 season
import pandas as pd
#query = 'SELECT '+(', '.join(toload))+' FROM Match'
players_ratings = pd.read_sql(query, conn)
#dfmatch = dfmatch[dfmatch['season']=='2016/2017']

# %%
players_ratings.drop(['id', 'player_fifa_api_id', 'player_api_id'], axis=1,inplace=True)
players_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181827 entries, 0 to 181826
# Data columns (total 43 columns):
# date                   181827 non-null object
# overall_rating         181827 non-null int64
# potential              181827 non-null int64
# preferred_foot         181827 non-null object
# attacking_work_rate    179464 non-null object
# defensive_work_rate    181827 non-null object
# crossing               181827 non-null int64
# finishing              181827 non-null int64
# heading_accuracy       181827 non-null int64
# short_passing          181827 non-null int64
# volleys                179975 non-null float64
# dribbling              181827 non-null int64
# curve                  179975 non-null float64
# free_kick_accuracy     181827 non-null int64
# long_passing           181827 non-null int64
# ball_control           181827 non-null int64
# acceleration           181827 non-null int64
# sprint_speed           181827 non-null int64
# agility                179975 non-null float64
# reactions              181827 non-null int64
# balance                179975 non-null float64
# shot_power             181827 non-null int64
# jumping                179975 non-null float64
# stamina                181827 non-null int64
# strength               181827 non-null int64
# long_shots             181827 non-null int64
# aggression             181827 non-null int64
# interceptions          181827 non-null int64
# positioning            181827 non-null int64
# vision                 179975 non-null float64
# penalties              181827 non-null int64
# marking                181827 non-null int64
# standing_tackle        181827 non-null int64
# sliding_tackle         179975 non-null float64
# gk_diving              181827 non-null int64
# gk_handling            181827 non-null int64
# gk_kicking             181827 non-null int64
# gk_positioning         181827 non-null int64
# gk_reflexes            181827 non-null int64
# player_name            181827 non-null object
# birthday               181827 non-null object
# height                 181827 non-null float64
# weight                 181827 non-null int64
# dtypes: float64(8), int64(29), object(6)
# memory usage: 59.7+ MB

# %%
players_ratings.dropna(axis=0,inplace=True)

# %%
#age
import datetime
players_ratings['birthday']=players_ratings['birthday'].astype('datetime64') 
players_ratings['date'] = players_ratings['date'].astype('datetime64')
now = pd.Timestamp(datetime.datetime.now())
#players_ratings['dob'] = players_ratings['birthday'].astype('datetime64') 
#players_ratings['dob'] = players_ratings['dob'].where(players_ratings['dob'] < now, players_ratings['date'] -  np.timedelta64(100, 'Y'))   # 2
players_ratings['age_at_date'] = (players_ratings['date'] - players_ratings['birthday']).astype('<m8[Y]') 
players_ratings['age'] = (now - players_ratings['date']).astype('<m8[Y]')

# %%
players_ratings.drop(['birthday'], axis=1,inplace=True)

# %%
players_ratings.head(100)
# Out:
#          date  overall_rating  potential preferred_foot attacking_work_rate  \
# 0  2007-02-22              61         65          right              medium
# 1  2015-03-20              61         65          right              medium
# 2  2015-09-21              62         66          right              medium
# 3  2015-11-19              67         71          right              medium
# 4  2016-02-18              67         71          right              medium
# 5  2007-02-22              53         60          right              medium
# 6  2008-08-30              53         60          right              medium
# 7  2009-02-22              47         60           left              medium
# 8  2009-08-30              52         65           left              medium
# 9  2010-02-22              51         64           left              medium
# 10 2010-08-30              54         65           left              medium
# 11 2011-08-30              64         68           left              medium
# 12 2012-02-22              65         68           left              medium
# 13 2012-08-31              68         80           left              medium
# 14 2013-02-15              69         80           left              medium
# 15 2013-02-22              69         80           left              medium
# 16 2013-03-15              69         80           left              medium
# 17 2013-03-22              69         80           left              medium
# 18 2013-05-03              69         80           left              medium
# 19 2013-09-20              69         79           left              medium
# 20 2013-10-04              69         79           left              medium
# 21 2013-11-08              70         79           left              medium
# 22 2013-12-13              70         79           left              medium
# 23 2014-03-14              70         79           left              medium
# 24 2014-04-04              70         79           left              medium
# 25 2014-05-02              70         79           left              medium
# 26 2014-09-18              70         77           left              medium
# 27 2014-11-07              71         77           left              medium
# 28 2014-12-05              71         77           left              medium
# 29 2015-01-09              71         75           left              medium
# ..        ...             ...        ...            ...                 ...
# 70 2011-08-30              69         70          right              medium
# 71 2012-02-22              69         70          right              medium
# 72 2012-08-31              70         70          right              medium
# 73 2013-02-15              68         70          right              medium
# 74 2013-05-10              68         68          right              medium
# 75 2013-09-20              67         67          right              medium
# 76 2014-04-11              67         67          right              medium
# 77 2014-06-06              67         67          right              medium
# 78 2014-09-18              67         67          right              medium
# 79 2014-11-14              67         67          right              medium
# 80 2015-01-16              67         67          right              medium
# 81 2015-06-12              67         67          right              medium
# 82 2015-07-03              67         67          right              medium
# 83 2015-09-21              69         69          right              medium
# 84 2015-10-02              69         69          right              medium
# 85 2015-10-16              69         69          right              medium
# 86 2016-04-21              69         69          right              medium
# 87 2007-02-22              75         75          right              medium
# 88 2007-08-30              71         78          right              medium
# 89 2008-08-30              72         78          right              medium
# 90 2009-02-22              75         81          right              medium
# 91 2009-08-30              78         81          right              medium
# 92 2010-02-22              78         81          right              medium
# 93 2010-08-30              76         81          right              medium
# 94 2011-02-22              75         81          right              medium
# 95 2011-08-30              76         76          right              medium
# 96 2012-02-22              75         75          right              medium
# 97 2012-08-31              74         74          right              medium
# 98 2013-02-15              74         74          right              medium
# 99 2013-03-08              74         74          right              medium
#
#    defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0               medium        48         43                70             60
# 1               medium        48         43                70             60
# 2               medium        49         44                71             61
# 3               medium        49         44                71             61
# 4               medium        49         44                71             61
# 5               medium        22         48                52             39
# 6               medium        22         48                52             39
# 7               medium        22         48                52             39
# 8               medium        58         40                52             45
# 9               medium        57         39                51             44
# 10              medium        58         40                52             45
# 11              medium        74         53                52             59
# 12              medium        77         53                52             62
# 13              medium        77         50                50             64
# 14              medium        77         50                50             64
# 15              medium        77         50                50             64
# 16              medium        77         50                50             64
# 17              medium        77         50                50             64
# 18              medium        77         50                50             64
# 19              medium        77         50                50             64
# 20              medium        77         50                50             64
# 21              medium        77         50                51             67
# 22              medium        77         50                51             67
# 23              medium        77         50                51             67
# 24              medium        77         50                51             67
# 25              medium        77         50                51             67
# 26              medium        77         50                51             67
# 27              medium        78         50                56             69
# 28              medium        78         50                56             69
# 29              medium        78         50                56             69
# ..                 ...       ...        ...               ...            ...
# 70                high        57         21                70             65
# 71              medium        57         21                70             65
# 72              medium        57         21                70             65
# 73              medium        57         21                68             65
# 74              medium        57         21                68             65
# 75              medium        57         21                68             65
# 76              medium        57         21                68             65
# 77              medium        57         21                68             65
# 78              medium        56         20                67             64
# 79              medium        56         20                67             64
# 80              medium        56         20                67             64
# 81              medium        56         20                67             64
# 82              medium        56         20                67             64
# 83              medium        57         21                68             65
# 84              medium        57         21                68             65
# 85              medium        57         21                68             65
# 86              medium        57         21                68             65
# 87              medium        45         57                76             54
# 88              medium        45         57                76             54
# 89              medium        45         57                76             54
# 90              medium        45         57                76             63
# 91              medium        45         57                76             66
# 92              medium        45         57                76             66
# 93              medium        45         33                72             66
# 94              medium        45         33                72             66
# 95              medium        45         33                72             66
# 96              medium        45         33                72             66
# 97              medium        45         33                72             66
# 98              medium        45         33                72             71
# 99              medium        45         33                72             71
#
#     ...    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 0   ...            5           10           9               7            7
# 1   ...            5           10           9               7            7
# 2   ...            6           11          10               8            8
# 3   ...            6           11          10               8            8
# 4   ...            6           11          10               8            8
# 5   ...            6           22          49              22           22
# 6   ...            6           22          49              22           22
# 7   ...            6           22          49              22           22
# 8   ...            6           22          46              22           22
# 9   ...            6           22          45              22           22
# 10  ...           13            6           8               8           11
# 11  ...           13            6           8               8           11
# 12  ...           13            6           8               8           11
# 13  ...           13            6           8               8           11
# 14  ...           13            6           8               8           11
# 15  ...           13            6           8               8           11
# 16  ...           13            6           8               8           11
# 17  ...           13            6           8               8           11
# 18  ...           13            6           8               8           11
# 19  ...           13            6           8               8           11
# 20  ...           13            6           8               8           11
# 21  ...           13            6           8               8           11
# 22  ...           13            6           8               8           11
# 23  ...           13            6           8               8           11
# 24  ...           13            6           8               8           11
# 25  ...           13            6           8               8           11
# 26  ...           13            6           8               8           11
# 27  ...           13            6           8               8           11
# 28  ...           13            6           8               8           11
# 29  ...           13            6           8               8           11
# ..  ...          ...          ...         ...             ...          ...
# 70  ...           14           11          12              11           10
# 71  ...           14           11          12              11           10
# 72  ...           14           11          12              11           10
# 73  ...           14           11          12              11           10
# 74  ...           14           11          12              11           10
# 75  ...           14           11          12              11           10
# 76  ...           14           11          12              11           10
# 77  ...           14           11          12              11           10
# 78  ...           14           11          12              11           10
# 79  ...           14           11          12              11           10
# 80  ...           14           11          12              11           10
# 81  ...           14           11          12              11           10
# 82  ...           14           11          12              11           10
# 83  ...           15           12          13              12           11
# 84  ...           15           12          13              12           11
# 85  ...           15           12          13              12           11
# 86  ...           15           12          13              12           11
# 87  ...           12           11          55              10            6
# 88  ...           12           20          55              20           20
# 89  ...           12           20          55              20           20
# 90  ...           12           20          57              20           20
# 91  ...           12           20          57              20           20
# 92  ...           12           20          57              20           20
# 93  ...            7            5          15              11           10
# 94  ...            7            5          15              11           10
# 95  ...            7            5          15              11           10
# 96  ...            7            5          15              11           10
# 97  ...            7            5          15              11           10
# 98  ...            7            5          15              11           10
# 99  ...            7            5          15              11           10
#
#            player_name  height  weight  age_at_date    age
# 0   Aaron Appindangoye 182.880     187       14.000 11.000
# 1   Aaron Appindangoye 182.880     187       23.000  3.000
# 2   Aaron Appindangoye 182.880     187       23.000  3.000
# 3   Aaron Appindangoye 182.880     187       23.000  3.000
# 4   Aaron Appindangoye 182.880     187       23.000  2.000
# 5      Aaron Cresswell 170.180     146       17.000 11.000
# 6      Aaron Cresswell 170.180     146       18.000 10.000
# 7      Aaron Cresswell 170.180     146       19.000  9.000
# 8      Aaron Cresswell 170.180     146       19.000  9.000
# 9      Aaron Cresswell 170.180     146       20.000  8.000
# 10     Aaron Cresswell 170.180     146       20.000  8.000
# 11     Aaron Cresswell 170.180     146       21.000  7.000
# 12     Aaron Cresswell 170.180     146       22.000  6.000
# 13     Aaron Cresswell 170.180     146       22.000  6.000
# 14     Aaron Cresswell 170.180     146       23.000  5.000
# 15     Aaron Cresswell 170.180     146       23.000  5.000
# 16     Aaron Cresswell 170.180     146       23.000  5.000
# 17     Aaron Cresswell 170.180     146       23.000  5.000
# 18     Aaron Cresswell 170.180     146       23.000  5.000
# 19     Aaron Cresswell 170.180     146       23.000  5.000
# 20     Aaron Cresswell 170.180     146       23.000  5.000
# 21     Aaron Cresswell 170.180     146       23.000  5.000
# 22     Aaron Cresswell 170.180     146       23.000  5.000
# 23     Aaron Cresswell 170.180     146       24.000  4.000
# 24     Aaron Cresswell 170.180     146       24.000  4.000
# 25     Aaron Cresswell 170.180     146       24.000  4.000
# 26     Aaron Cresswell 170.180     146       24.000  4.000
# 27     Aaron Cresswell 170.180     146       24.000  4.000
# 28     Aaron Cresswell 170.180     146       24.000  4.000
# 29     Aaron Cresswell 170.180     146       25.000  4.000
# ..                 ...     ...     ...          ...    ...
# 70       Aaron Galindo 182.880     198       29.000  7.000
# 71       Aaron Galindo 182.880     198       29.000  6.000
# 72       Aaron Galindo 182.880     198       30.000  6.000
# 73       Aaron Galindo 182.880     198       30.000  5.000
# 74       Aaron Galindo 182.880     198       31.000  5.000
# 75       Aaron Galindo 182.880     198       31.000  5.000
# 76       Aaron Galindo 182.880     198       31.000  4.000
# 77       Aaron Galindo 182.880     198       32.000  4.000
# 78       Aaron Galindo 182.880     198       32.000  4.000
# 79       Aaron Galindo 182.880     198       32.000  4.000
# 80       Aaron Galindo 182.880     198       32.000  4.000
# 81       Aaron Galindo 182.880     198       33.000  3.000
# 82       Aaron Galindo 182.880     198       33.000  3.000
# 83       Aaron Galindo 182.880     198       33.000  3.000
# 84       Aaron Galindo 182.880     198       33.000  3.000
# 85       Aaron Galindo 182.880     198       33.000  3.000
# 86       Aaron Galindo 182.880     198       33.000  2.000
# 87        Aaron Hughes 182.880     154       27.000 11.000
# 88        Aaron Hughes 182.880     154       27.000 11.000
# 89        Aaron Hughes 182.880     154       28.000 10.000
# 90        Aaron Hughes 182.880     154       29.000  9.000
# 91        Aaron Hughes 182.880     154       29.000  9.000
# 92        Aaron Hughes 182.880     154       30.000  8.000
# 93        Aaron Hughes 182.880     154       30.000  8.000
# 94        Aaron Hughes 182.880     154       31.000  7.000
# 95        Aaron Hughes 182.880     154       31.000  7.000
# 96        Aaron Hughes 182.880     154       32.000  6.000
# 97        Aaron Hughes 182.880     154       32.000  6.000
# 98        Aaron Hughes 182.880     154       33.000  5.000
# 99        Aaron Hughes 182.880     154       33.000  5.000
#
# [100 rows x 44 columns]

# %%
Messi=players_ratings[players_ratings['player_name']=='Lionel Messi']
Ronaldo=players_ratings[players_ratings['player_name']=='Cristiano Ronaldo']
Salah=players_ratings[players_ratings['player_name']=='Mohamed Salah']

# %%
players_ratings['total_attacking']=players_ratings[ ['crossing','finishing','heading_accuracy',
       'short_passing','volleys']].sum()
players_ratings['total_skills']=

# %%
Salah
# Out:
#             id  player_fifa_api_id  player_api_id       date  overall_rating  \
# 126549  128048              209331         292462 2007-02-22              70
# 126550  128047              209331         292462 2012-08-31              70
# 126551  128046              209331         292462 2013-02-15              70
# 126552  128045              209331         292462 2013-03-08              73
# 126553  128044              209331         292462 2013-03-22              73
# 126554  128043              209331         292462 2013-09-20              74
# 126555  128042              209331         292462 2013-10-04              75
# 126556  128041              209331         292462 2013-11-01              75
# 126557  128040              209331         292462 2013-12-13              75
# 126558  128039              209331         292462 2014-01-10              75
# 126559  128038              209331         292462 2014-01-31              77
# 126560  128037              209331         292462 2014-05-16              77
# 126561  128036              209331         292462 2014-09-18              76
# 126562  128035              209331         292462 2015-02-06              76
# 126563  128034              209331         292462 2015-03-06              76
# 126564  128033              209331         292462 2015-03-13              76
# 126565  128032              209331         292462 2015-03-20              76
# 126566  128031              209331         292462 2015-04-24              77
# 126567  128030              209331         292462 2015-07-03              77
# 126568  128029              209331         292462 2015-09-21              80
# 126569  128028              209331         292462 2015-10-09              80
# 126570  128027              209331         292462 2015-11-12              80
# 126571  128026              209331         292462 2015-12-17              80
# 126572  128025              209331         292462 2016-04-21              80
# 126573  128024              209331         292462 2016-05-05              80
#
#         potential preferred_foot attacking_work_rate defensive_work_rate  \
# 126549         82           left                high              medium
# 126550         82           left                high              medium
# 126551         82           left                high              medium
# 126552         82           left                high              medium
# 126553         82           left                high              medium
# 126554         85           left                high              medium
# 126555         85           left                high              medium
# 126556         85           left                high              medium
# 126557         85           left                high              medium
# 126558         86           left                high              medium
# 126559         87           left                high              medium
# 126560         87           left                high              medium
# 126561         84           left                high              medium
# 126562         84           left                high              medium
# 126563         84           left                high              medium
# 126564         84           left                high              medium
# 126565         84           left                high              medium
# 126566         84           left                high              medium
# 126567         84           left                high              medium
# 126568         87           left                high              medium
# 126569         87           left                high              medium
# 126570         85           left                high              medium
# 126571         85           left                high              medium
# 126572         85           left                high              medium
# 126573         85           left                high              medium
#
#         crossing   ...    gk_kicking  gk_positioning  gk_reflexes    id  \
# 126549        61   ...             8              10           13  7665
# 126550        61   ...             8              10           13  7665
# 126551        61   ...             8              10           13  7665
# 126552        61   ...             8              10           13  7665
# 126553        61   ...             8              10           13  7665
# 126554        61   ...             8              10           13  7665
# 126555        61   ...             8              10           13  7665
# 126556        61   ...             8              10           13  7665
# 126557        61   ...             8              10           13  7665
# 126558        61   ...             8              10           13  7665
# 126559        65   ...             8              10           13  7665
# 126560        65   ...             8              10           13  7665
# 126561        67   ...             8              10           13  7665
# 126562        67   ...             8              10           13  7665
# 126563        67   ...             8              10           13  7665
# 126564        67   ...             8              10           13  7665
# 126565        67   ...             8              10           13  7665
# 126566        67   ...             8              10           13  7665
# 126567        67   ...             8              10           13  7665
# 126568        68   ...             9              11           14  7665
# 126569        68   ...             9              11           14  7665
# 126570        68   ...             9              11           14  7665
# 126571        68   ...             9              11           14  7665
# 126572        68   ...             9              11           14  7665
# 126573        68   ...             9              11           14  7665
#
#         player_api_id    player_name  player_fifa_api_id             birthday  \
# 126549         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126550         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126551         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126552         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126553         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126554         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126555         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126556         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126557         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126558         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126559         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126560         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126561         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126562         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126563         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126564         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126565         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126566         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126567         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126568         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126569         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126570         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126571         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126572         292462  Mohamed Salah              209331  1992-06-15 00:00:00
# 126573         292462  Mohamed Salah              209331  1992-06-15 00:00:00
#
#         height  weight
# 126549 175.260     159
# 126550 175.260     159
# 126551 175.260     159
# 126552 175.260     159
# 126553 175.260     159
# 126554 175.260     159
# 126555 175.260     159
# 126556 175.260     159
# 126557 175.260     159
# 126558 175.260     159
# 126559 175.260     159
# 126560 175.260     159
# 126561 175.260     159
# 126562 175.260     159
# 126563 175.260     159
# 126564 175.260     159
# 126565 175.260     159
# 126566 175.260     159
# 126567 175.260     159
# 126568 175.260     159
# 126569 175.260     159
# 126570 175.260     159
# 126571 175.260     159
# 126572 175.260     159
# 126573 175.260     159
#
# [25 rows x 49 columns]

# %%
Salah['overall_rating']
Salah.plot('date','overall_rating')
#plt.ylabel("Daily sales")

# %%
players_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44450 entries, 7 to 181826
# Data columns (total 49 columns):
# id                     44450 non-null int64
# player_fifa_api_id     44450 non-null int64
# player_api_id          44450 non-null int64
# date                   44450 non-null datetime64[ns]
# overall_rating         44450 non-null int64
# potential              44450 non-null int64
# preferred_foot         44450 non-null object
# attacking_work_rate    43925 non-null object
# defensive_work_rate    44450 non-null object
# crossing               44450 non-null int64
# finishing              44450 non-null int64
# heading_accuracy       44450 non-null int64
# short_passing          44450 non-null int64
# volleys                44036 non-null float64
# dribbling              44450 non-null int64
# curve                  44036 non-null float64
# free_kick_accuracy     44450 non-null int64
# long_passing           44450 non-null int64
# ball_control           44450 non-null int64
# acceleration           44450 non-null int64
# sprint_speed           44450 non-null int64
# agility                44036 non-null float64
# reactions              44450 non-null int64
# balance                44036 non-null float64
# shot_power             44450 non-null int64
# jumping                44036 non-null float64
# stamina                44450 non-null int64
# strength               44450 non-null int64
# long_shots             44450 non-null int64
# aggression             44450 non-null int64
# interceptions          44450 non-null int64
# positioning            44450 non-null int64
# vision                 44036 non-null float64
# penalties              44450 non-null int64
# marking                44450 non-null int64
# standing_tackle        44450 non-null int64
# sliding_tackle         44036 non-null float64
# gk_diving              44450 non-null int64
# gk_handling            44450 non-null int64
# gk_kicking             44450 non-null int64
# gk_positioning         44450 non-null int64
# gk_reflexes            44450 non-null int64
# id                     44450 non-null int64
# player_api_id          44450 non-null int64
# player_name            44450 non-null object
# player_fifa_api_id     44450 non-null int64
# birthday               44450 non-null object
# height                 44450 non-null float64
# weight                 44450 non-null int64
# dtypes: datetime64[ns](1), float64(8), int64(35), object(5)
# memory usage: 17.0+ MB

# %%
#LabelEncoding using Pipeline
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.preprocessing import LabelEncoder, Imputer
from scipy.stats import skew
# One hot encoding class
class onehotenc(BaseEstimator,TransformerMixin):
    def __init__(self):
        pass
    def fit(self,X,y=None):
        return self
    def transform(self,X):
        X = pd.get_dummies(X)
        return X

# %%
aggregates=players_ratings.groupby(players_ratings['player_name']).agg({'height':'mean','weight':'mean','gk_kicking':'mean'})
aggregates.hist(figsize = (8, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efe11332b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efe0deba048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7efe0dfb20b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efe0dd3e710>]],
#       dtype=object)

# %%
fig, ax= plt.subplots()
aggregates.hist(figsize = (8, 10))
fig.savefig('some_features_distributions.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-9c7fef546ce3> in <module>
#       1 fig, ax= plt.subplots()
# ----> 2 aggregates.plt.hist(figsize = (8, 10))
#       3 fig.savefig('some_features_distributions.png')
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %% [markdown]
#  Once loaded, explore what type of information it contains, what data types are present, and calculate some basic quantities (for example: the average funds raised)

# %%
df.describe(include=['O'])
# Out:
#             company_permalink company_name company_category_list  \
# count                  114505       114504                111242
# unique                  32334        32283                 11874
# top     /organization/fab-com          Fab       |Biotechnology|
# freq                       60           60                  7762
#
#        company_market company_country_code company_state_code company_region  \
# count          111240               107146              79158         107146
# unique            712                  101                 61            965
# top          Software                  USA                 CA    SF Bay Area
# freq             9906                76523              39101          32120
#
#          company_city             investor_permalink    investor_name  \
# count          105800                         114439           114439
# unique           2901                          22275            22036
# top     San Francisco  /organization/sequoia-capital  Sequoia Capital
# freq            14287                            776              776
#
#               ...         investor_region investor_city  \
# count         ...                   86521         86007
# unique        ...                     589          1381
# top           ...             SF Bay Area    Menlo Park
# freq          ...                   27269          9962
#
#                                 funding_round_permalink funding_round_type  \
# count                                            114505             114505
# unique                                            50279                 13
# top     /funding-round/e7d7980d9469411c5ccdefb37c3912f1            venture
# freq                                                 38              70615
#
#        funding_round_code   funded_at funded_month funded_quarter  \
# count               54669      114505       114505         114505
# unique                  8        3922          299            122
# top                     A  2012-01-01      2014-01        2014-Q1
# freq                21708         795         2200           5812
#
#        raised_amount_total_usd raised_amount_each
# count                   101154             114505
# unique                    7453                  2
# top                10,000,000             #DIV/0!
# freq                      3385             101154
#
# [4 rows x 24 columns]

# %%
columns_list=df.columns.tolist()
df.nunique()
# Out:
# company_permalink          32334
# company_name               32283
# company_category_list      11874
# company_market               712
# company_country_code         101
# company_state_code            61
# company_region               965
# company_city                2901
# investor_permalink         22275
# investor_name              22036
# investor_category_list      1160
# investor_market              272
# investor_country_code         85
# investor_state_code           59
# investor_region              589
# investor_city               1381
# funding_round_permalink    50279
# funding_round_type            13
# funding_round_code             8
# funded_at                   3922
# funded_month                 299
# funded_quarter               122
# funded_year                   35
# raised_amount_total_usd     7453
# raised_amount_each             2
# dtype: int64

# %%
#for i in range(5000,10000):#len(df['funded_quarter'])):
    #df['funded_month'].iloc[i]=df['funded_month'].iloc[i][5:]
    #df['funded_quarter'].iloc[i]=df['funded_quarter'].iloc[i][5:]

# %%
#converting type "object" to "datetime" for column "date" 
df['funded_at'] = df['funded_at'].astype('datetime64')
df.info()
#Sorting the values by 'date'
#df.sort_values(by='date', inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114505 entries, 0 to 114504
# Data columns (total 25 columns):
# company_permalink          114505 non-null object
# company_name               114504 non-null object
# company_category_list      111242 non-null object
# company_market             111240 non-null object
# company_country_code       107146 non-null object
# company_state_code         79158 non-null object
# company_region             107146 non-null object
# company_city               105800 non-null object
# investor_permalink         114439 non-null object
# investor_name              114439 non-null object
# investor_category_list     30507 non-null object
# investor_market            30455 non-null object
# investor_country_code      86521 non-null object
# investor_state_code        62274 non-null object
# investor_region            86521 non-null object
# investor_city              86007 non-null object
# funding_round_permalink    114505 non-null object
# funding_round_type         114505 non-null object
# funding_round_code         54669 non-null object
# funded_at                  114505 non-null datetime64[ns]
# funded_month               114505 non-null object
# funded_quarter             114505 non-null object
# funded_year                114505 non-null int64
# raised_amount_total_usd    101154 non-null object
# raised_amount_each         114505 non-null object
# dtypes: datetime64[ns](1), int64(1), object(23)
# memory usage: 21.8+ MB

# %%
df["raised_amount_total_usd"].replace(['',' -   '], np.nan, inplace=True)

# %%
#df=df[df['funding_round_type']!= 'undisclosed']

# %%
df[df['investor_name']=='137 Ventures']
# Out:
#                           company_permalink           company_name  \
# 44162   /organization/palantir-technologies  Palantir Technologies
# 44230               /organization/solarcity              SolarCity
# 44325                   /organization/visto                  Visto
# 56876                /organization/50-cubes               50 Cubes
# 57101              /organization/eventbrite             Eventbrite
# 57148               /organization/glammedia             Mode Media
# 57414         /organization/practice-fusion        Practice Fusion
# 57491               /organization/sharethis              ShareThis
# 57525          /organization/specific-media         Specific Media
# 57530                 /organization/spotify                Spotify
# 57589                  /organization/tumblr                 Tumblr
# 73478                  /organization/apptio                 Apptio
# 73835   /organization/palantir-technologies  Palantir Technologies
# 102332             /organization/present-tv                Present
#
#                                     company_category_list  \
# 44162                                         |Analytics|
# 44230                     |Construction|Clean Technology|
# 44325                                            |Mobile|
# 56876          |Fashion|Social Games|Online Gaming|Women|
# 57101                                |Events|Curated Web|
# 57148                         |Women|Fashion|Curated Web|
# 57414   |Physicians|Electronic Health Records|Health C...
# 57491             |Advertising|File Sharing|Social Media|
# 57525                |Auctions|Digital Media|Advertising|
# 57530   |Entertainment|Cloud Computing|Video Streaming...
# 57589           |Opinions|Blogging Platforms|Curated Web|
# 73478             |Corporate IT|SaaS|Enterprise Software|
# 73835                                         |Analytics|
# 102332  |Artificial Intelligence|Computer Vision|Video...
#
#              company_market company_country_code company_state_code  \
# 44162             Analytics                  USA                 CA
# 44230          Construction                  USA                 CA
# 44325                Mobile                  USA                 CA
# 56876                 Women                  USA                 CA
# 57101                Events                  USA                 CA
# 57148               Fashion                  USA                 CA
# 57414   Health and Wellness                  USA                 CA
# 57491          Social Media                  USA                 CA
# 57525           Advertising                  USA                 CA
# 57530         Entertainment                  SWE                NaN
# 57589              Opinions                  USA                 NY
# 73478                  SaaS                  USA                 WA
# 73835             Analytics                  USA                 CA
# 102332      Computer Vision                  USA                 NJ
#
#        company_region   company_city          investor_permalink  \
# 44162     SF Bay Area      Palo Alto  /organization/137-ventures
# 44230     SF Bay Area      San Mateo  /organization/137-ventures
# 44325     SF Bay Area      Sunnyvale  /organization/137-ventures
# 56876     SF Bay Area  San Francisco  /organization/137-ventures
# 57101     SF Bay Area  San Francisco  /organization/137-ventures
# 57148     SF Bay Area       Brisbane  /organization/137-ventures
# 57414     SF Bay Area  San Francisco  /organization/137-ventures
# 57491     SF Bay Area      Palo Alto  /organization/137-ventures
# 57525         Anaheim         Irvine  /organization/137-ventures
# 57530       Stockholm      Stockholm  /organization/137-ventures
# 57589   New York City       New York  /organization/137-ventures
# 73478         Seattle       Bellevue  /organization/137-ventures
# 73835     SF Bay Area      Palo Alto  /organization/137-ventures
# 102332         Newark      Princeton  /organization/137-ventures
#
#        investor_name        ...          investor_city  \
# 44162   137 Ventures        ...          San Francisco
# 44230   137 Ventures        ...          San Francisco
# 44325   137 Ventures        ...          San Francisco
# 56876   137 Ventures        ...          San Francisco
# 57101   137 Ventures        ...          San Francisco
# 57148   137 Ventures        ...          San Francisco
# 57414   137 Ventures        ...          San Francisco
# 57491   137 Ventures        ...          San Francisco
# 57525   137 Ventures        ...          San Francisco
# 57530   137 Ventures        ...          San Francisco
# 57589   137 Ventures        ...          San Francisco
# 73478   137 Ventures        ...          San Francisco
# 73835   137 Ventures        ...          San Francisco
# 102332  137 Ventures        ...          San Francisco
#
#                                 funding_round_permalink funding_round_type  \
# 44162   /funding-round/9b6ea97f7014cc52dc0a5c2f9d1654b1   secondary_market
# 44230   /funding-round/58100d6e6670124f53ec62a207b62409   secondary_market
# 44325   /funding-round/034768749e447bd217077c21b27cfb12   secondary_market
# 56876   /funding-round/1cadd2472b35324e4e28b104d8e509b1   secondary_market
# 57101   /funding-round/0c2cd93429982bc6ce65e91d3848efa8   secondary_market
# 57148   /funding-round/24a9447e37f7a5ac1fcb177b920b01a1   secondary_market
# 57414   /funding-round/873bee968cebf49a1885e22d00fe212e   secondary_market
# 57491   /funding-round/547140d92e2791643b92b3f4d20dc2c8   secondary_market
# 57525   /funding-round/2649ae4917aee301f6e55a20e971acd2   secondary_market
# 57530   /funding-round/05e3129f24145ddac7f7115f115607c7   secondary_market
# 57589   /funding-round/40bedfc36e95410761f4a6f12576b020   secondary_market
# 73478   /funding-round/7596140c90f36daf13fe6cd7e392776f   secondary_market
# 73835   /funding-round/f683e2ffad9619a45dfc3e1c186faf4f   secondary_market
# 102332  /funding-round/13a7bfb75d838fda3a574ca40af365a7   convertible_note
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 44162                 NaN  2011-01-01      2011-01        2011-Q1        2011
# 44230                 NaN  2011-01-01      2011-01        2011-Q1        2011
# 44325                 NaN  2011-01-01      2011-01        2011-Q1        2011
# 56876                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57101                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57148                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57414                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57491                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57525                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57530                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 57589                 NaN  2012-01-01      2012-01        2012-Q1        2012
# 73478                 NaN  2013-01-01      2013-01        2013-Q1        2013
# 73835                 NaN  2013-01-01      2013-01        2013-Q1        2013
# 102332                NaN  2014-05-01      2014-05        2014-Q2        2014
#
#        raised_amount_total_usd raised_amount_each
# 44162                      NaN               -
# 44230                      NaN               -
# 44325                      NaN               -
# 56876                      NaN               -
# 57101                      NaN               -
# 57148                      NaN               -
# 57414                      NaN               -
# 57491                      NaN               -
# 57525                      NaN               -
# 57530                      NaN               -
# 57589                      NaN               -
# 73478                      NaN               -
# 73835                      NaN               -
# 102332                     NaN               -
#
# [14 rows x 25 columns]

# %%
#for i in range(len(df["raised_amount_total_usd"])):
    #if df['investor_name'].iloc[i]=='10Xelerator':
        #df["raised_amount_total_usd"].iloc[i]=20000

# %%
df['funding_round_type'][df["raised_amount_total_usd"].isnull()]
# Out:
# 0                   seed
# 7            undisclosed
# 8                venture
# 12           undisclosed
# 13           undisclosed
# 14           undisclosed
# 15           undisclosed
# 16           undisclosed
# 17           undisclosed
# 19           undisclosed
# 20               venture
# 21               venture
# 22           undisclosed
# 24           undisclosed
# 25           undisclosed
# 26           undisclosed
# 27           undisclosed
# 28           undisclosed
# 29           undisclosed
# 31           undisclosed
# 32           undisclosed
# 33           undisclosed
# 34           undisclosed
# 35           undisclosed
# 36           undisclosed
# 37           undisclosed
# 38           undisclosed
# 39           undisclosed
# 40           undisclosed
# 41           undisclosed
#                ...
# 114125       undisclosed
# 114161              seed
# 114180           venture
# 114181           venture
# 114189             angel
# 114190             angel
# 114191             angel
# 114192             angel
# 114193             angel
# 114208           venture
# 114211              seed
# 114214           venture
# 114218           venture
# 114219           venture
# 114221    private_equity
# 114223           venture
# 114259           venture
# 114260           venture
# 114276       undisclosed
# 114303       undisclosed
# 114335       undisclosed
# 114355           venture
# 114383           venture
# 114384           venture
# 114385           venture
# 114386           venture
# 114387           venture
# 114412              seed
# 114455           venture
# 114456           venture
# Name: funding_round_type, Length: 13351, dtype: object

# %%
#df["raised_amount_total_usd"].str.split()
df["raised_amount_total_usd"].replace(',','',regex=True,inplace=True)
df["raised_amount_total_usd"]=pd.to_numeric(df["raised_amount_total_usd"],).astype(float)

# %%
company_state_cod

# %%
#inv=df[df["raised_amount_total_usd"].isnull()].groupby(df['funding_round_type'])
USA=df[df['company_country_code']=='USA']
#inv=USA.groupby(df['company_state_code', 'funded_year'])["raised_amount_total_usd"]
USA.head()
# Out:
#                   company_permalink       company_name  company_category_list  \
# 1            /organization/abo-data           ABO Data  |Enterprise Software|
# 2            /organization/abo-data           ABO Data  |Enterprise Software|
# 7              /organization/lenovo             Lenovo             |Hardware|
# 12  /organization/aehr-test-systems  Aehr Test Systems  |Hardware + Software|
# 13  /organization/fsi-international  FSI International       |Semiconductors|
#
#          company_market company_country_code company_state_code  \
# 1   Enterprise Software                  USA                 TX
# 2   Enterprise Software                  USA                 TX
# 7              Hardware                  USA                 NC
# 12  Hardware + Software                  USA                 CA
# 13       Semiconductors                  USA                 MN
#
#    company_region company_city                         investor_permalink  \
# 1      TX - Other        Italy                    /person/antonio-murroni
# 2      TX - Other        Italy                    /person/filippo-murroni
# 7         Raleigh  Morrisville  /organization/chinese-academy-of-sciences
# 12    SF Bay Area      Fremont              /organization/summit-partners
# 13    Minneapolis       Chaska              /organization/summit-partners
#
#                   investor_name        ...         investor_city  \
# 1               ANTONIO MURRONI        ...                   NaN
# 2               FILIPPO Murroni        ...                   NaN
# 7   Chinese Academy Of Sciences        ...               Beijing
# 12              Summit Partners        ...                Boston
# 13              Summit Partners        ...                Boston
#
#                             funding_round_permalink funding_round_type  \
# 1   /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 2   /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 7   /funding-round/0f444f3fdb0c1058aa70eeba9f0f5089        undisclosed
# 12  /funding-round/3b02cf325be61412c2af1eb545f4d568        undisclosed
# 13  /funding-round/34b482e681b7e2ec7b0c7886e9f9d90d        undisclosed
#
#    funding_round_code  funded_at funded_month funded_quarter funded_year  \
# 1                 NaN 1979-01-01      1979-01        1979-Q1        1979
# 2                 NaN 1979-01-01      1979-01        1979-Q1        1979
# 7                 NaN 1984-01-01      1984-01        1984-Q1        1984
# 12                NaN 1985-09-19      1985-09        1985-Q3        1985
# 13                NaN 1985-10-20      1985-10        1985-Q4        1985
#
#    raised_amount_total_usd raised_amount_each
# 1              1000000.000            #DIV/0!
# 2              1000000.000            #DIV/0!
# 7                      nan               -
# 12                     nan               -
# 13                     nan               -
#
# [5 rows x 25 columns]

# %%
g8 = df[df.company_country_code.isin(['USA', 'GBR', 'FRA', 'GER', 'JPN', 'CAN', 'ITA'])]

# %%
g8
# Out:
#                                      company_permalink  \
# 0                  /organization/andrewburnett-com-ltd
# 1                               /organization/abo-data
# 2                               /organization/abo-data
# 7                                 /organization/lenovo
# 12                     /organization/aehr-test-systems
# 13                     /organization/fsi-international
# 14                /organization/employee-benefit-plans
# 16                               /organization/telebit
# 17                /organization/chips-and-technologies
# 18                                 /organization/cisco
# 19                /organization/integrated-systems-inc
# 22                         /organization/clean-harbors
# 24              /organization/digital-link-corporation
# 25         /organization/platinum-software-corporation
# 26      /organization/litchfield-financial-corporation
# 27                         /organization/future-domain
# 28                          /organization/office-depot
# 29         /organization/software-spectrum-corporation
# 30                   /organization/knowledge-adventure
# 31            /organization/saber-software-corporation
# 32                         /organization/software-2000
# 33                               /organization/archive
# 34                           /organization/intellution
# 35            /organization/pharmaco-dynamics-research
# 37               /organization/renal-treatment-centers
# 38                              /organization/artisoft
# 39              /organization/active-voice-corporation
# 40                          /organization/imageamerica
# 41                               /organization/lincare
# 42                           /organization/market-wire
# ...                                                ...
# 114451                         /organization/vox-media
# 114453           /organization/apellis-pharmaceuticals
# 114454           /organization/apellis-pharmaceuticals
# 114457             /organization/audentes-therapeutics
# 114458             /organization/audentes-therapeutics
# 114459             /organization/audentes-therapeutics
# 114460             /organization/audentes-therapeutics
# 114461             /organization/audentes-therapeutics
# 114462             /organization/audentes-therapeutics
# 114466                /organization/cognitive-networks
# 114467                /organization/cognitive-networks
# 114468                /organization/cognitive-networks
# 114475                            /organization/inmobi
# 114476                       /organization/lancers-inc
# 114477                       /organization/lancers-inc
# 114478                       /organization/lancers-inc
# 114479                       /organization/lancers-inc
# 114480                       /organization/lancers-inc
# 114484                          /organization/sendgrid
# 114485                          /organization/sendgrid
# 114486                          /organization/sendgrid
# 114489                             /organization/strap
# 114490                             /organization/strap
# 114491                             /organization/strap
# 114492                             /organization/strap
# 114493                             /organization/strap
# 114494                             /organization/strap
# 114498                      /organization/viaforensics
# 114499                      /organization/viaforensics
# 114500                      /organization/viaforensics
#
#                             company_name  \
# 0                  AndrewBurnett.com Ltd
# 1                               ABO Data
# 2                               ABO Data
# 7                                 Lenovo
# 12                     Aehr Test Systems
# 13                     FSI International
# 14                Employee Benefit Plans
# 16                               Telebit
# 17                Chips and Technologies
# 18                                 Cisco
# 19               Integrated Systems Inc.
# 22                         Clean Harbors
# 24              Digital Link Corporation
# 25         Platinum Software Corporation
# 26      Litchfield Financial Corporation
# 27                         Future Domain
# 28                          Office Depot
# 29         Software Spectrum Corporation
# 30                   Knowledge Adventure
# 31            Saber Software Corporation
# 32                         Software 2000
# 33                               Archive
# 34                           Intellution
# 35            Pharmaco Dynamics Research
# 37               Renal Treatment Centers
# 38                              Artisoft
# 39              Active Voice Corporation
# 40                           MedAlliance
# 41                               Lincare
# 42                           Market Wire
# ...                                  ...
# 114451                         Vox Media
# 114453           Apellis Pharmaceuticals
# 114454           Apellis Pharmaceuticals
# 114457             Audentes Therapeutics
# 114458             Audentes Therapeutics
# 114459             Audentes Therapeutics
# 114460             Audentes Therapeutics
# 114461             Audentes Therapeutics
# 114462             Audentes Therapeutics
# 114466                Cognitive Networks
# 114467                Cognitive Networks
# 114468                Cognitive Networks
# 114475                            InMobi
# 114476                       lancers Inc
# 114477                       lancers Inc
# 114478                       lancers Inc
# 114479                       lancers Inc
# 114480                       lancers Inc
# 114484                          SendGrid
# 114485                          SendGrid
# 114486                          SendGrid
# 114489                             Strap
# 114490                             Strap
# 114491                             Strap
# 114492                             Strap
# 114493                             Strap
# 114494                             Strap
# 114498                         NowSecure
# 114499                         NowSecure
# 114500                         NowSecure
#
#                                     company_category_list  \
# 0       |Internet|SEO|Services|Public Relations|Social...
# 1                                   |Enterprise Software|
# 2                                   |Enterprise Software|
# 7                                              |Hardware|
# 12                                  |Hardware + Software|
# 13                                       |Semiconductors|
# 14                                                    NaN
# 16                                                    NaN
# 17                                       |Semiconductors|
# 18             |Software|Hardware|Networking|Web Hosting|
# 19                                                    NaN
# 22                                     |Clean Technology|
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                           |E-Commerce|
# 29                                                    NaN
# 30                                                |Games|
# 31                                                    NaN
# 32                                                    NaN
# 33                                                    NaN
# 34                                                    NaN
# 35                                                    NaN
# 37                                                    NaN
# 38                                                    NaN
# 39                                         |Social Media|
# 40                                                    NaN
# 41                                                    NaN
# 42                                          |Advertising|
# ...                                                   ...
# 114451                   |Sports|Blogging Platforms|News|
# 114453                                    |Biotechnology|
# 114454                                    |Biotechnology|
# 114457                                    |Biotechnology|
# 114458                                    |Biotechnology|
# 114459                                    |Biotechnology|
# 114460                                    |Biotechnology|
# 114461                                    |Biotechnology|
# 114462                                    |Biotechnology|
# 114466                                |Image Recognition|
# 114467                                |Image Recognition|
# 114468                                |Image Recognition|
# 114475                               |Advertising|Mobile|
# 114476                        |Crowdsourcing|Curated Web|
# 114477                        |Crowdsourcing|Curated Web|
# 114478                        |Crowdsourcing|Curated Web|
# 114479                        |Crowdsourcing|Curated Web|
# 114480                        |Crowdsourcing|Curated Web|
# 114484                      |Finance|Enterprise Software|
# 114485                      |Finance|Enterprise Software|
# 114486                      |Finance|Enterprise Software|
# 114489                                             |Apps|
# 114490                                             |Apps|
# 114491                                             |Apps|
# 114492                                             |Apps|
# 114493                                             |Apps|
# 114494                                             |Apps|
# 114498         |Software|Apps|Mobile Security|Technology|
# 114499         |Software|Apps|Mobile Security|Technology|
# 114500         |Software|Apps|Mobile Security|Technology|
#
#              company_market company_country_code company_state_code  \
# 0                  Internet                  GBR                NaN
# 1       Enterprise Software                  USA                 TX
# 2       Enterprise Software                  USA                 TX
# 7                  Hardware                  USA                 NC
# 12      Hardware + Software                  USA                 CA
# 13           Semiconductors                  USA                 MN
# 14                      NaN                  USA                 MN
# 16                      NaN                  USA                 MA
# 17           Semiconductors                  USA                 CA
# 18                 Software                  USA                 CA
# 19                      NaN                  USA                 CA
# 22         Clean Technology                  USA                 MA
# 24                      NaN                  USA                 CA
# 25                      NaN                  USA                 CA
# 26                      NaN                  USA                 VT
# 27                      NaN                  USA                 CA
# 28               E-Commerce                  USA                 FL
# 29                      NaN                  USA                 TX
# 30                    Games                  USA                 CA
# 31                      NaN                  USA                 TX
# 32                      NaN                  USA                 MA
# 33                      NaN                  USA                 CA
# 34                      NaN                  USA                 MA
# 35                      NaN                  USA                 TX
# 37                      NaN                  USA                 PA
# 38                      NaN                  USA                 AZ
# 39             Social Media                  USA                 WA
# 40                      NaN                  USA                 MA
# 41                      NaN                  USA                 FL
# 42              Advertising                  USA                 CA
# ...                     ...                  ...                ...
# 114451               Sports                  USA                 DC
# 114453        Biotechnology                  USA                 KY
# 114454        Biotechnology                  USA                 KY
# 114457        Biotechnology                  USA                 CA
# 114458        Biotechnology                  USA                 CA
# 114459        Biotechnology                  USA                 CA
# 114460        Biotechnology                  USA                 CA
# 114461        Biotechnology                  USA                 CA
# 114462        Biotechnology                  USA                 CA
# 114466    Image Recognition                  USA                 CA
# 114467    Image Recognition                  USA                 CA
# 114468    Image Recognition                  USA                 CA
# 114475               Mobile                  USA                 CA
# 114476        Crowdsourcing                  JPN                NaN
# 114477        Crowdsourcing                  JPN                NaN
# 114478        Crowdsourcing                  JPN                NaN
# 114479        Crowdsourcing                  JPN                NaN
# 114480        Crowdsourcing                  JPN                NaN
# 114484              Finance                  USA                 CO
# 114485              Finance                  USA                 CO
# 114486              Finance                  USA                 CO
# 114489                 Apps                  USA                 OH
# 114490                 Apps                  USA                 OH
# 114491                 Apps                  USA                 OH
# 114492                 Apps                  USA                 OH
# 114493                 Apps                  USA                 OH
# 114494                 Apps                  USA                 OH
# 114498                 Apps                  USA                 IL
# 114499                 Apps                  USA                 IL
# 114500                 Apps                  USA                 IL
#
#           company_region   company_city  \
# 0              Edinburgh      Edinburgh
# 1             TX - Other          Italy
# 2             TX - Other          Italy
# 7                Raleigh    Morrisville
# 12           SF Bay Area        Fremont
# 13           Minneapolis         Chaska
# 14           Minneapolis    Minneapolis
# 16                Boston     Chelmsford
# 17           SF Bay Area       Milpitas
# 18           SF Bay Area       San Jose
# 19           SF Bay Area    Santa Clara
# 22                Boston        Norwell
# 24           SF Bay Area      Sunnyvale
# 25               Anaheim         Irvine
# 26            VT - Other       Stamford
# 27               Anaheim         Irvine
# 28          Palm Beaches     Boca Raton
# 29                Dallas        Garland
# 30           Los Angeles       Torrance
# 31                Dallas         Dallas
# 32              Cape Cod   Hyannis Port
# 33               Anaheim     Costa Mesa
# 34                Boston        Norwood
# 35                Austin         Austin
# 37          Philadelphia         Berwyn
# 38                Tucson         Tucson
# 39               Seattle        Seattle
# 40                Boston        Maynard
# 41                 Tampa     Clearwater
# 42           Los Angeles     El Segundo
# ...                  ...            ...
# 114451  Washington, D.C.     Washington
# 114453        Louisville      Crestwood
# 114454        Louisville      Crestwood
# 114457       SF Bay Area  San Francisco
# 114458       SF Bay Area  San Francisco
# 114459       SF Bay Area  San Francisco
# 114460       SF Bay Area  San Francisco
# 114461       SF Bay Area  San Francisco
# 114462       SF Bay Area  San Francisco
# 114466       SF Bay Area  San Francisco
# 114467       SF Bay Area  San Francisco
# 114468       SF Bay Area  San Francisco
# 114475       SF Bay Area  San Francisco
# 114476             Tokyo          Tokyo
# 114477             Tokyo          Tokyo
# 114478             Tokyo          Tokyo
# 114479             Tokyo          Tokyo
# 114480             Tokyo          Tokyo
# 114484            Denver        Boulder
# 114485            Denver        Boulder
# 114486            Denver        Boulder
# 114489        Cincinnati     Cincinnati
# 114490        Cincinnati     Cincinnati
# 114491        Cincinnati     Cincinnati
# 114492        Cincinnati     Cincinnati
# 114493        Cincinnati     Cincinnati
# 114494        Cincinnati     Cincinnati
# 114498           Chicago       Oak Park
# 114499           Chicago       Oak Park
# 114500           Chicago       Oak Park
#
#                                    investor_permalink  \
# 0                                  /organization/ekaf
# 1                             /person/antonio-murroni
# 2                             /person/filippo-murroni
# 7           /organization/chinese-academy-of-sciences
# 12                      /organization/summit-partners
# 13                      /organization/summit-partners
# 14                      /organization/summit-partners
# 16                      /organization/summit-partners
# 17                      /organization/summit-partners
# 18                      /organization/sequoia-capital
# 19                      /organization/summit-partners
# 22                      /organization/summit-partners
# 24                      /organization/summit-partners
# 25                      /organization/summit-partners
# 26                      /organization/summit-partners
# 27                      /organization/summit-partners
# 28                     /organization/upfront-ventures
# 29                      /organization/summit-partners
# 30                              /person/william-lohse
# 31                      /organization/summit-partners
# 32                      /organization/summit-partners
# 33                      /organization/summit-partners
# 34                      /organization/summit-partners
# 35                      /organization/summit-partners
# 37                      /organization/summit-partners
# 38                      /organization/summit-partners
# 39                      /organization/summit-partners
# 40                      /organization/summit-partners
# 41                      /organization/summit-partners
# 42      /organization/hummer-winblad-venture-partners
# ...                                               ...
# 114451                 /organization/general-atlantic
# 114453                /organization/aju-ib-investment
# 114454    /organization/morningside-private-investors
# 114457                     /organization/5am-ventures
# 114458             /organization/deerfield-management
# 114459                 /organization/orbimed-advisors
# 114460               /organization/sofinnova-ventures
# 114461                          /organization/venrock
# 114462                 /organization/versant-ventures
# 114466                 /organization/dcl-ventures-inc
# 114467                  /organization/hearst-ventures
# 114468          /organization/rogers-venture-partners
# 114475                         /organization/softbank
# 114476                           /organization/colopl
# 114477          /organization/globis-capital-partners
# 114478             /organization/gmo-venture-partners
# 114479                    /organization/gree-ventures
# 114480                             /organization/kddi
# 114484            /organization/bain-capital-ventures
# 114485        /organization/bessemer-venture-partners
# 114486                    /organization/foundry-group
# 114489                        /organization/cincytech
# 114490       /organization/hyde-park-venture-partners
# 114491                     /organization/mercury-fund
# 114492                 /organization/vine-st-ventures
# 114493                          /person/trevor-wright
# 114494                              /person/wendy-lea
# 114498                    /organization/baird-capital
# 114499                     /organization/jump-capital
# 114500            /organization/math-venture-partners
#
#                           investor_name        ...          investor_city  \
# 0                                  Ekaf        ...                    NaN
# 1                       ANTONIO MURRONI        ...                    NaN
# 2                       FILIPPO Murroni        ...                    NaN
# 7           Chinese Academy Of Sciences        ...                Beijing
# 12                      Summit Partners        ...                 Boston
# 13                      Summit Partners        ...                 Boston
# 14                      Summit Partners        ...                 Boston
# 16                      Summit Partners        ...                 Boston
# 17                      Summit Partners        ...                 Boston
# 18                      Sequoia Capital        ...             Menlo Park
# 19                      Summit Partners        ...                 Boston
# 22                      Summit Partners        ...                 Boston
# 24                      Summit Partners        ...                 Boston
# 25                      Summit Partners        ...                 Boston
# 26                      Summit Partners        ...                 Boston
# 27                      Summit Partners        ...                 Boston
# 28                     Upfront Ventures        ...            Los Angeles
# 29                      Summit Partners        ...                 Boston
# 30                        William Lohse        ...                    NaN
# 31                      Summit Partners        ...                 Boston
# 32                      Summit Partners        ...                 Boston
# 33                      Summit Partners        ...                 Boston
# 34                      Summit Partners        ...                 Boston
# 35                      Summit Partners        ...                 Boston
# 37                      Summit Partners        ...                 Boston
# 38                      Summit Partners        ...                 Boston
# 39                      Summit Partners        ...                 Boston
# 40                      Summit Partners        ...                 Boston
# 41                      Summit Partners        ...                 Boston
# 42      Hummer Winblad Venture Partners        ...          San Francisco
# ...                                 ...        ...                    ...
# 114451                 General Atlantic        ...               New York
# 114453                Aju IB Investment        ...                  Seoul
# 114454    Morningside Private Investors        ...             Ridgefield
# 114457                     5AM Ventures        ...             Menlo Park
# 114458     Deerfield Capital Management        ...               Rosamond
# 114459                 OrbiMed Advisors        ...               New York
# 114460               Sofinnova Ventures        ...             Menlo Park
# 114461                          Venrock        ...              Palo Alto
# 114462                 Versant Ventures        ...             Menlo Park
# 114466               DCL Ventures, Inc.        ...               New York
# 114467                  Hearst Ventures        ...               New York
# 114468          Rogers Venture Partners        ...              Palo Alto
# 114475                         SoftBank        ...                  Tokyo
# 114476                           COLOPL        ...                    NaN
# 114477          Globis Capital Partners        ...                  Tokyo
# 114478             GMO Venture Partners        ...                  Tokyo
# 114479                    GREE Ventures        ...                  Tokyo
# 114480                             KDDI        ...                  Tokyo
# 114484            Bain Capital Ventures        ...                 Boston
# 114485        Bessemer Venture Partners        ...             Menlo Park
# 114486                    Foundry Group        ...                Boulder
# 114489                        CincyTech        ...             Cincinnati
# 114490       Hyde Park Venture Partners        ...                Chicago
# 114491                     Mercury Fund        ...                Houston
# 114492                Vine St. Ventures        ...                    NaN
# 114493                    Trevor Wright        ...                    NaN
# 114494                        Wendy Lea        ...                    NaN
# 114498                    Baird Capital        ...                 London
# 114499                     Jump Capital        ...                Chicago
# 114500            Math Venture Partners        ...                Chicago
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/14fe2864e02d0f15ddc3ec8eacdc8e1b               seed
# 1       /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 2       /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 7       /funding-round/0f444f3fdb0c1058aa70eeba9f0f5089        undisclosed
# 12      /funding-round/3b02cf325be61412c2af1eb545f4d568        undisclosed
# 13      /funding-round/34b482e681b7e2ec7b0c7886e9f9d90d        undisclosed
# 14      /funding-round/e54edf8a94111d1bdf7d1e0557701de7        undisclosed
# 16      /funding-round/3eedb6f3bf848731988dfa083acc4acc        undisclosed
# 17      /funding-round/a1ebcbd1921a3ef94baa3bc40c4e7905        undisclosed
# 18      /funding-round/b9911ec2e19ad490dcdeb2d0d1a87c97            venture
# 19      /funding-round/0f6062afbaf0c7459b8da9d1d569b4ac        undisclosed
# 22      /funding-round/c6d7201edacb3a9e581273ec1389c7f4        undisclosed
# 24      /funding-round/1c9f5321dd4378c1555c7ab7654e6611        undisclosed
# 25      /funding-round/5d355ef3cba2555275668ffb62452b81        undisclosed
# 26      /funding-round/d74f596dfbb9f93dc2dae38a06f69ace        undisclosed
# 27      /funding-round/0b0e1ce7be6cd4c58c593775a6f0e2c7        undisclosed
# 28      /funding-round/920c9faf245bda1669be1ec36bcb5896        undisclosed
# 29      /funding-round/968812b5fa03ad56d306961534a72b61        undisclosed
# 30      /funding-round/04081f1e737343aefe19db52a1f10da7               seed
# 31      /funding-round/5a8983579ae0ab9667701e5288dd30e4        undisclosed
# 32      /funding-round/84d3eac88589e6e3307910e42c474d57        undisclosed
# 33      /funding-round/4afc726b2eb2a17e8669a1aafd299958        undisclosed
# 34      /funding-round/4bcd7cccd5cece19d90da24f47cc4052        undisclosed
# 35      /funding-round/d19cdb67bade9315a750381257eecf9f        undisclosed
# 37      /funding-round/9c464ad44611204dc3e5c08482a1362d        undisclosed
# 38      /funding-round/7abf76dc7a6352b85c3de441522a09c6        undisclosed
# 39      /funding-round/13bfa7d2ab7aebc0f31361dc35094efb        undisclosed
# 40      /funding-round/0294842ef0228f9d4fe834b4bbd79fae        undisclosed
# 41      /funding-round/c621640d415eec1cbe11a0f13ac72205        undisclosed
# 42      /funding-round/21db75043beb906b60235ca557f2d375            venture
# ...                                                 ...                ...
# 114451  /funding-round/8d8ca20f2e4dcf7b753ccc2acc1b9cca            venture
# 114453  /funding-round/b5ca362aeff24661677c31d79db6cc31            venture
# 114454  /funding-round/b5ca362aeff24661677c31d79db6cc31            venture
# 114457  /funding-round/96a2392473565ea7eb7e13b3d001256c            venture
# 114458  /funding-round/96a2392473565ea7eb7e13b3d001256c            venture
# 114459  /funding-round/96a2392473565ea7eb7e13b3d001256c            venture
# 114460  /funding-round/96a2392473565ea7eb7e13b3d001256c            venture
# 114461  /funding-round/96a2392473565ea7eb7e13b3d001256c            venture
# 114462  /funding-round/96a2392473565ea7eb7e13b3d001256c            venture
# 114466  /funding-round/0ce1ec51dad6a227618fdd4b429c7ecd            venture
# 114467  /funding-round/0ce1ec51dad6a227618fdd4b429c7ecd            venture
# 114468  /funding-round/0ce1ec51dad6a227618fdd4b429c7ecd            venture
# 114475  /funding-round/d52970d84ec24fac1a2b24d67fc8dc50            venture
# 114476  /funding-round/bc281b35f3cafe6fc1c50622704d6983            venture
# 114477  /funding-round/bc281b35f3cafe6fc1c50622704d6983            venture
# 114478  /funding-round/bc281b35f3cafe6fc1c50622704d6983            venture
# 114479  /funding-round/bc281b35f3cafe6fc1c50622704d6983            venture
# 114480  /funding-round/bc281b35f3cafe6fc1c50622704d6983            venture
# 114484  /funding-round/8f0cf2ea42b258de4fa5ff04d6d67025            venture
# 114485  /funding-round/8f0cf2ea42b258de4fa5ff04d6d67025            venture
# 114486  /funding-round/8f0cf2ea42b258de4fa5ff04d6d67025            venture
# 114489  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114490  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114491  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114492  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114493  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114494  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114498  /funding-round/5356815dd7aea01531d656ded8ff2381            venture
# 114499  /funding-round/5356815dd7aea01531d656ded8ff2381            venture
# 114500  /funding-round/5356815dd7aea01531d656ded8ff2381            venture
#
#        funding_round_code  funded_at funded_month funded_quarter funded_year  \
# 0                     NaN 1974-01-01      1974-01        1974-Q1        1974
# 1                     NaN 1979-01-01      1979-01        1979-Q1        1979
# 2                     NaN 1979-01-01      1979-01        1979-Q1        1979
# 7                     NaN 1984-01-01      1984-01        1984-Q1        1984
# 12                    NaN 1985-09-19      1985-09        1985-Q3        1985
# 13                    NaN 1985-10-20      1985-10        1985-Q4        1985
# 14                    NaN 1986-03-19      1986-03        1986-Q1        1986
# 16                    NaN 1986-06-20      1986-06        1986-Q2        1986
# 17                    NaN 1986-07-03      1986-07        1986-Q3        1986
# 18                      A 1987-01-01      1987-01        1987-Q1        1987
# 19                    NaN 1987-04-03      1987-04        1987-Q2        1987
# 22                    NaN 1987-08-18      1987-08        1987-Q3        1987
# 24                    NaN 1987-12-23      1987-12        1987-Q4        1987
# 25                    NaN 1988-09-29      1988-09        1988-Q3        1988
# 26                    NaN 1988-11-21      1988-11        1988-Q4        1988
# 27                    NaN 1989-03-07      1989-03        1989-Q1        1989
# 28                    NaN 1989-06-01      1989-06        1989-Q2        1989
# 29                    NaN 1989-12-01      1989-12        1989-Q4        1989
# 30                    NaN 1990-01-01      1990-01        1990-Q1        1990
# 31                    NaN 1990-02-23      1990-02        1990-Q1        1990
# 32                    NaN 1990-04-18      1990-04        1990-Q2        1990
# 33                    NaN 1990-05-14      1990-05        1990-Q2        1990
# 34                    NaN 1990-07-17      1990-07        1990-Q3        1990
# 35                    NaN 1990-08-10      1990-08        1990-Q3        1990
# 37                    NaN 1990-09-28      1990-09        1990-Q3        1990
# 38                    NaN 1990-10-15      1990-10        1990-Q4        1990
# 39                    NaN 1990-10-31      1990-10        1990-Q4        1990
# 40                    NaN 1990-11-09      1990-11        1990-Q4        1990
# 41                    NaN 1990-11-29      1990-11        1990-Q4        1990
# 42                      A 1990-11-30      1990-11        1990-Q4        1990
# ...                   ...        ...          ...            ...         ...
# 114451                  E 2014-12-01      2014-12        2014-Q4        2014
# 114453                  C 2014-12-02      2014-12        2014-Q4        2014
# 114454                  C 2014-12-02      2014-12        2014-Q4        2014
# 114457                  B 2014-12-02      2014-12        2014-Q4        2014
# 114458                  B 2014-12-02      2014-12        2014-Q4        2014
# 114459                  B 2014-12-02      2014-12        2014-Q4        2014
# 114460                  B 2014-12-02      2014-12        2014-Q4        2014
# 114461                  B 2014-12-02      2014-12        2014-Q4        2014
# 114462                  B 2014-12-02      2014-12        2014-Q4        2014
# 114466                  B 2014-12-02      2014-12        2014-Q4        2014
# 114467                  B 2014-12-02      2014-12        2014-Q4        2014
# 114468                  B 2014-12-02      2014-12        2014-Q4        2014
# 114475                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114476                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114477                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114478                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114479                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114480                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114484                  C 2014-12-02      2014-12        2014-Q4        2014
# 114485                  C 2014-12-02      2014-12        2014-Q4        2014
# 114486                  C 2014-12-02      2014-12        2014-Q4        2014
# 114489                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114490                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114491                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114492                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114493                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114494                NaN 2014-12-02      2014-12        2014-Q4        2014
# 114498                  A 2014-12-02      2014-12        2014-Q4        2014
# 114499                  A 2014-12-02      2014-12        2014-Q4        2014
# 114500                  A 2014-12-02      2014-12        2014-Q4        2014
#
#        raised_amount_total_usd raised_amount_each
# 0                          nan               -
# 1                  1000000.000            #DIV/0!
# 2                  1000000.000            #DIV/0!
# 7                          nan               -
# 12                         nan               -
# 13                         nan               -
# 14                         nan               -
# 16                         nan               -
# 17                         nan               -
# 18                 2500000.000            #DIV/0!
# 19                         nan               -
# 22                         nan               -
# 24                         nan               -
# 25                         nan               -
# 26                         nan               -
# 27                         nan               -
# 28                         nan               -
# 29                         nan               -
# 30                   60000.000            #DIV/0!
# 31                         nan               -
# 32                         nan               -
# 33                         nan               -
# 34                         nan               -
# 35                         nan               -
# 37                         nan               -
# 38                         nan               -
# 39                         nan               -
# 40                         nan               -
# 41                         nan               -
# 42                17550000.000            #DIV/0!
# ...                        ...                ...
# 114451            46500000.000            #DIV/0!
# 114453            33000000.000            #DIV/0!
# 114454            33000000.000            #DIV/0!
# 114457            42500000.000            #DIV/0!
# 114458            42500000.000            #DIV/0!
# 114459            42500000.000            #DIV/0!
# 114460            42500000.000            #DIV/0!
# 114461            42500000.000            #DIV/0!
# 114462            42500000.000            #DIV/0!
# 114466            14500000.000            #DIV/0!
# 114467            14500000.000            #DIV/0!
# 114468            14500000.000            #DIV/0!
# 114475             5000000.000            #DIV/0!
# 114476             8450000.000            #DIV/0!
# 114477             8450000.000            #DIV/0!
# 114478             8450000.000            #DIV/0!
# 114479             8450000.000            #DIV/0!
# 114480             8450000.000            #DIV/0!
# 114484            20000000.000            #DIV/0!
# 114485            20000000.000            #DIV/0!
# 114486            20000000.000            #DIV/0!
# 114489             1200000.000            #DIV/0!
# 114490             1200000.000            #DIV/0!
# 114491             1200000.000            #DIV/0!
# 114492             1200000.000            #DIV/0!
# 114493             1200000.000            #DIV/0!
# 114494             1200000.000            #DIV/0!
# 114498            12500000.000            #DIV/0!
# 114499            12500000.000            #DIV/0!
# 114500            12500000.000            #DIV/0!
#
# [88181 rows x 25 columns]

# %%
g8plot=g8.groupby(['company_country_code','funded_year'])['raised_amount_total_usd'].sum()

# %%
unstack=g8plot.unstack('funded_year')
unstack=[:,25:]
# Out:
#   File "<ipython-input-50-fd8d7bf9629d>", line 1
#     g8plot.unstack('funded_year')=g8plot.unstack('funded_year')[25:,:]
#                                                                       ^
# SyntaxError: can't assign to function call

# %%
g8_countries=['USA', 'GBR', 'FRA', 'GER', 'JPN', 'CAN', 'ITA']

# %%
for i in g8_countries:
    historical_trend=pd.DataFrame(g8.groupby([i,'funded_year']).agg({'raised_amount_total_usd':'sum'}))
    historical_trend.plot()
    plt.ylabel("Amount of Investments in G8 countries"+str(i))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-bb5afd0af0aa> in <module>
#       1 for i in g8_countries:
# ----> 2     historical_trend=pd.DataFrame(g8.groupby([i,'funded_year']).agg({'raised_amount_total_usd':'sum'}))
#       3     historical_trend.plot()
#       4     plt.ylabel("Amount of Investments in G8 countries"+str(i))
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'USA'

# %%
USA.groupby(['company_state_code','funded_year'])['raised_amount_total_usd'].sum()
# Out:
# company_state_code  funded_year
# AK                  2007              8700000.000
#                     2014               150000.000
# AL                  2006             14000000.000
#                     2007             12925000.000
#                     2008              7750000.000
#                     2009             12000000.000
#                     2010                    0.000
#                     2011              1800000.000
#                     2012             29400000.000
#                     2013             21410000.000
#                     2014             14299999.000
# AR                  2006             15050000.000
#                     2008            495000000.000
#                     2009               500000.000
#                     2010             15010000.000
#                     2012             25058333.000
#                     2013            102039999.000
#                     2014             56642355.000
# AZ                  1990                    0.000
#                     1991                    0.000
#                     1995                    0.000
#                     1999              3345280.000
#                     2003             26316000.000
#                     2004                    0.000
#                     2005             80360000.000
#                     2006             49800000.000
#                     2007            255190000.000
#                     2008            294000000.000
#                     2009            693811600.000
#                     2010             86185700.000
#                                         ...
# WA                  2003             31100000.000
#                     2004             80100000.000
#                     2005           2037360000.000
#                     2006           2091620000.000
#                     2007           3080921868.000
#                     2008          17914899749.000
#                     2009          15167176760.000
#                     2010           1591350139.000
#                     2011           1493200838.000
#                     2012           2728421068.000
#                     2013           3303227269.000
#                     2014           3177263616.000
# WI                  1994                    0.000
#                     2000                    0.000
#                     2002             51000000.000
#                     2005              4000000.000
#                     2006             79100000.000
#                     2007             57650000.000
#                     2008             37350000.000
#                     2009             15494196.000
#                     2010            275193038.000
#                     2011             95750000.000
#                     2012             52197000.000
#                     2013             90113299.000
#                     2014            488322000.000
# WV                  2005              3000000.000
#                     2008                    0.000
#                     2010                    0.000
#                     2013                    0.000
# WY                  2010             10000000.000
# Name: raised_amount_total_usd, Length: 656, dtype: float64

# %%
daily_trend=pd.DataFrame(df.groupby(['funded_at']).agg({'raised_amount_total_usd':'sum'}))
daily_trend.plot()
plt.ylabel("Amount of Investments")
# Out:
# Text(0, 0.5, 'Amount of Investments')

# %%
df["raised_amount_total_usd"][7242]
# Out:
# nan
